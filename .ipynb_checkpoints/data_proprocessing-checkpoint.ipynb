# %%
import pandas as pd
df = pd.read_csv('/home/jbmai_sai/Desktop/climate/train_dataset.csv')

print(df.isnull().sum())

print(df.isna().sum())
# Out:
# date_time              0
# is_holiday             0
# air_pollution_index    0
# humidity               0
# wind_speed             0
# wind_direction         0
# visibility_in_miles    0
# dew_point              0
# temperature            0
# rain_p_h               0
# snow_p_h               0
# clouds_all             0
# weather_type           0
# weather_description    0
# traffic_volume         0
# dtype: int64
# date_time              0
# is_holiday             0
# air_pollution_index    0
# humidity               0
# wind_speed             0
# wind_direction         0
# visibility_in_miles    0
# dew_point              0
# temperature            0
# rain_p_h               0
# snow_p_h               0
# clouds_all             0
# weather_type           0
# weather_description    0
# traffic_volume         0
# dtype: int64

# %%
df = pd.concat([df,pd.get_dummies(df['weather_type'], prefix='weather_type')],axis=1)

for i in df.index:
    day = df['is_holiday'].loc[i]
    if(day != 'None'):
        df['is_holiday'].loc[i] = 'holiday'
        
df = pd.concat([df,pd.get_dummies(df['is_holiday'], prefix='is_holiday')],axis=1)

df = pd.concat([df,pd.get_dummies(df['weather_description'], prefix='weather_description')],axis=1)

new = df["date_time"].str.split(" ", n = 1, expand = True) 
  
# making separate first name column from new data frame 
df["date"]= new[0] 
  
# making separate last name column from new data frame 
df["time"]= new[1] 

new = df["date"].str.split("-", n = 2, expand = True) 
  
# making separate first name column from new data frame 
df["year"]= new[0] 
  
# making separate last name column from new data frame 
df["month"]= new[1] 
df["day"] = new[2]
  
# Dropping old Name columns 
new = df["time"].str.split(":", n = 1, expand = True) 
  
# making separate first name column from new data frame 
df["hour"]= new[0]

# %%
df.drop(columns = ['weather_description','date_time','date','time','is_holiday','weather_type'], inplace = True)
d = df
df_y = df['traffic_volume']

df.drop(columns = ['traffic_volume'],inplace = True)
d = df

# %%
df["year"] = pd.to_numeric(df["year"])
df["month"] = pd.to_numeric(df["month"])
df["day"] = pd.to_numeric(df["day"])
df["hour"] = pd.to_numeric(df["hour"])

# %%
df.head()
# Out:
#    air_pollution_index  humidity  wind_speed  wind_direction  \
# 0                   94        82           1             322
# 1                  177        87           1             311
# 2                   38        81           0             352
# 3                   46        75           1             351
# 4                   29        58           2               3
#
#    visibility_in_miles  dew_point  temperature  rain_p_h  snow_p_h  \
# 0                    2          2       289.58       0.0       0.0
# 1                    6          6       288.22       0.0       0.0
# 2                    8          8       287.66       0.0       0.0
# 3                    9          9       286.92       0.0       0.0
# 4                    9          9       286.91       0.0       0.0
#
#    clouds_all  ...  weather_description_thunderstorm  \
# 0           8  ...                                 0
# 1          12  ...                                 0
# ...

# %%
df=((df-df.min())/(df.max()-df.min()))*20.0

# %%
df['snow_p_h']=0.0
df.isnull().sum()
# Out:
# air_pollution_index                                        0
# humidity                                                   0
# wind_speed                                                 0
# wind_direction                                             0
# visibility_in_miles                                        0
# dew_point                                                  0
# temperature                                                0
# rain_p_h                                                   0
# snow_p_h                                                   0
# clouds_all                                                 0
# weather_type_Clear                                         0
# weather_type_Clouds                                        0
# weather_type_Drizzle                                       0
# weather_type_Fog                                           0
# weather_type_Haze                                          0
# ...

# %%
df['month'] = d['month']
df['hour']  = d['hour']
df['day'] = d['day']

# %%
# This is only ran for preparation of test data (currently a bit hard-coded)

df['weather_type_Squall'] = 0.0
df['weather_description_freezing rain'] = 0.0
df['weather_description_heavy snow'] = 0.0
df['weather_description_light rain and snow'] = 0.0
df['weather_description_light shower snow'] = 0.0
df['weather_description_shower drizzle'] = 0.0
df['weather_description_shower snow'] = 0.0
df['weather_description_thunderstorm with drizzle'] = 0.0
df['weather_description_SQUALLS'] = 0.0

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4707 entries, 0 to 4706
# Data columns (total 65 columns):
# air_pollution_index                                        4707 non-null float64
# humidity                                                   4707 non-null float64
# wind_speed                                                 4707 non-null float64
# wind_direction                                             4707 non-null float64
# visibility_in_miles                                        4707 non-null float64
# dew_point                                                  4707 non-null float64
# temperature                                                4707 non-null float64
# rain_p_h                                                   4707 non-null float64
# snow_p_h                                                   4707 non-null float64
# clouds_all                                                 4707 non-null float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4707 entries, 0 to 4706
# Data columns (total 65 columns):
# air_pollution_index                                        4707 non-null float64
# humidity                                                   4707 non-null float64
# wind_speed                                                 4707 non-null float64
# wind_direction                                             4707 non-null float64
# visibility_in_miles                                        4707 non-null float64
# dew_point                                                  4707 non-null float64
# temperature                                                4707 non-null float64
# rain_p_h                                                   4707 non-null float64
# snow_p_h                                                   4707 non-null float64
# clouds_all                                                 4707 non-null float64
# ...

# %%
cols = list(df.columns.values)
cols.sort() 
df = df[cols]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4707 entries, 0 to 4706
# Data columns (total 65 columns):
# air_pollution_index                                        4707 non-null float64
# clouds_all                                                 4707 non-null float64
# day                                                        4707 non-null int64
# dew_point                                                  4707 non-null float64
# hour                                                       4707 non-null int64
# humidity                                                   4707 non-null float64
# is_holiday_None                                            4707 non-null float64
# is_holiday_holiday                                         4707 non-null float64
# month                                                      4707 non-null int64
# rain_p_h                                                   4707 non-null float64
# ...

# %%
cols = list(df.columns.values)
cols.sort() 
df = df[cols]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4707 entries, 0 to 4706
# Data columns (total 65 columns):
# air_pollution_index                                        4707 non-null float64
# clouds_all                                                 4707 non-null float64
# day                                                        4707 non-null int64
# dew_point                                                  4707 non-null float64
# hour                                                       4707 non-null int64
# humidity                                                   4707 non-null float64
# is_holiday_None                                            4707 non-null float64
# is_holiday_holiday                                         4707 non-null float64
# month                                                      4707 non-null int64
# rain_p_h                                                   4707 non-null float64
# ...

# %%
df = df.to_numpy()
#df_y = df_y.to_numpy()

# %%
import numpy as np
np.save('/home/jbmai_sai/Desktop/climate/test_x.npy', df)
#np.save('/home/jbmai_sai/Desktop/climate/train_y.npy', df_y)
